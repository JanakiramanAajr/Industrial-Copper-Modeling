# %%
# importing pandas for dataframe
import pandas as pd

# %%
# df-->dataframe
df = pd.read_csv('/content/Copper_Set.xlsx - Result 1.csv')
df
# Out:
# <ipython-input-2-7544fbfa5403>:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Copper_Set.xlsx - Result 1.csv')
#                                           id   item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
# ...                                      ...         ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0   102.4824216
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0   208.0864686
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0   4.235593568
# ...

# %%
df.set_index('id', inplace = True)
df
# Out:
#                                        item_date quantity tons    customer  \
# id
# EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139  30156308.0
# 4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839  30202938.0
# E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949  30153963.0
# F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065  30349574.0
# 4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262  30211560.0
# ...                                          ...           ...         ...
# DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0   102.4824216  30200854.0
# A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0   208.0864686  30200854.0
# 91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0   4.235593568  30200854.0
# 7AFFD323-01D9-4E15-B80D-7D1B03498FC8  20200702.0         -2000  30200854.0
# AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  20200702.0   406.6865384  30200854.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 181673 entries, EC06F063-9DF0-440C-8764-0B0C05A4F6AE to AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_date      181672 non-null  float64
#  1   quantity tons  181673 non-null  object
#  2   customer       181672 non-null  float64
#  3   country        181645 non-null  float64
#  4   status         181671 non-null  object
#  5   item type      181673 non-null  object
#  6   application    181649 non-null  float64
#  7   thickness      181672 non-null  float64
#  8   width          181673 non-null  float64
#  9   material_ref   103754 non-null  object
#  10  product_ref    181673 non-null  int64
#  11  delivery date  181672 non-null  float64
#  12  selling_price  181672 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 19.4+ MB

# %%
df.shape
# Out:
# (181673, 13)

# %%
#importing ordinal encoder for unique data in a column to numerical data
from sklearn.preprocessing import OrdinalEncoder

# %%
df['status'].unique()
# Out:
# array(['Won', 'Draft', 'To be approved', 'Lost', 'Not lost for AM',
#        'Wonderful', 'Revised', 'Offered', 'Offerable', nan], dtype=object)

# %%
df.status.fillna('To be approved',inplace=True)

# %%
df['status'].unique()
# Out:
# array(['Won', 'Draft', 'To be approved', 'Lost', 'Not lost for AM',
#        'Wonderful', 'Revised', 'Offered', 'Offerable'], dtype=object)

# %%
eng = OrdinalEncoder()
df['status'] = eng.fit_transform(df[['status']])

# %%
df['status'].unique() #7-->Won, 0--> Draft, 6--> To be approved, 1--> lost, 2--> Not lost for AM, 8--> Wonderful, 5--> Reversed, 4--> Offered, 3--> Offerable
# Out:
# array([7., 0., 6., 1., 2., 8., 5., 4., 3.])

# %%
df['item type'].unique()
# Out:
# array(['W', 'WI', 'S', 'Others', 'PL', 'IPL', 'SLAWR'], dtype=object)

# %%
eng = OrdinalEncoder()
df['item type'] = eng.fit_transform(df[['item type']])

# %%
df['item type'].unique() #asper the previous data
# Out:
# array([5., 6., 3., 1., 2., 0., 4.])

# %%
df['material_ref'].unique()
# Out:
# array(['DEQ1 S460MC', '0000000000000000000000000000000000104991',
#        'S0380700', ..., 'MAS65550', '4.11043_1060X5_BRE',
#        '202006170005.IO.1.1'], dtype=object)

# %%
eng = OrdinalEncoder()
df['material_ref'] = eng.fit_transform(df[['item type']])

# %%
df['material_ref'].unique()#asper the previous data
# Out:
# array([5., 6., 3., 1., 2., 0., 4.])

# %%
df['quantity tons'].unique()
# Out:
# array([54.15113862, 768.0248392, 386.1279489, ..., '4.235593568', '-2000',
#        '406.6865384'], dtype=object)

# %%
# df['quantity tons'] = df['quantity tons'].astype(str).astype(float)# the value of e will be given concider it as exp-value because quantity in tons

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# In this data the quantity is in the ton so it is considered as the e--> exp()
import math
e=math.exp(1)
e
# Out:
# 2.718281828459045

# %%
df['quantity tons'].replace(to_replace='e',value=e,inplace=True)

# %%
df['quantity tons'] = df['quantity tons'].astype(str).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 181673 entries, EC06F063-9DF0-440C-8764-0B0C05A4F6AE to AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_date      181672 non-null  float64
#  1   quantity tons  181673 non-null  float64
#  2   customer       181672 non-null  float64
#  3   country        181645 non-null  float64
#  4   status         181673 non-null  float64
#  5   item type      181673 non-null  float64
#  6   application    181649 non-null  float64
#  7   thickness      181672 non-null  float64
#  8   width          181673 non-null  float64
#  9   material_ref   181673 non-null  float64
#  10  product_ref    181673 non-null  int64
#  11  delivery date  181672 non-null  float64
#  12  selling_price  181672 non-null  float64
# dtypes: float64(12), int64(1)
# memory usage: 19.4+ MB

# %%
df.isnull().sum()
# Out:
# item_date         1
# quantity tons     0
# customer          1
# country          28
# status            0
# item type         0
# application      24
# thickness         1
# width             0
# material_ref      0
# product_ref       0
# delivery date     1
# selling_price     1
# dtype: int64

# %%
df.country.fillna(0,inplace=True)
df.application.fillna(0,inplace =True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# item_date        0
# quantity tons    0
# customer         0
# country          0
# status           0
# item type        0
# application      0
# thickness        0
# width            0
# material_ref     0
# product_ref      0
# delivery date    0
# selling_price    0
# dtype: int64

# %%
for i in df['item_date']:
  if i==19:
    print(i)
print(i)
# Out:
# 20200702.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 181668 entries, EC06F063-9DF0-440C-8764-0B0C05A4F6AE to AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_date      181668 non-null  float64
#  1   quantity tons  181668 non-null  float64
#  2   customer       181668 non-null  float64
#  3   country        181668 non-null  float64
#  4   status         181668 non-null  float64
#  5   item type      181668 non-null  float64
#  6   application    181668 non-null  float64
#  7   thickness      181668 non-null  float64
#  8   width          181668 non-null  float64
#  9   material_ref   181668 non-null  float64
#  10  product_ref    181668 non-null  int64
#  11  delivery date  181668 non-null  float64
#  12  selling_price  181668 non-null  float64
# dtypes: float64(12), int64(1)
# memory usage: 19.4+ MB

# %%
df.drop_duplicates()
# Out:
#                                        item_date  quantity tons    customer  \
# id
# EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0      54.151139  30156308.0
# 4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0     768.024839  30202938.0
# E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0     386.127949  30153963.0
# F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0     202.411065  30349574.0
# 4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0     785.526262  30211560.0
# ...                                          ...            ...         ...
# DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0     102.482422  30200854.0
# A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0     208.086469  30200854.0
# 91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0       4.235594  30200854.0
# 7AFFD323-01D9-4E15-B80D-7D1B03498FC8  20200702.0   -2000.000000  30200854.0
# AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  20200702.0     406.686538  30200854.0
#
# ...

# %%
y = df['selling_price']
x = df.drop(['selling_price'], axis = 1)

# %%
x
# Out:
#                                        item_date  quantity tons    customer  \
# id
# EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0      54.151139  30156308.0
# 4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0     768.024839  30202938.0
# E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0     386.127949  30153963.0
# F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0     202.411065  30349574.0
# 4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0     785.526262  30211560.0
# ...                                          ...            ...         ...
# DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0     102.482422  30200854.0
# A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0     208.086469  30200854.0
# 91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0       4.235594  30200854.0
# 7AFFD323-01D9-4E15-B80D-7D1B03498FC8  20200702.0   -2000.000000  30200854.0
# AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  20200702.0     406.686538  30200854.0
#
# ...

# %%
import random
j=x.product_ref.unique()
k= random.choice(j)
k
# Out:
# 164337175

# %%
y
# Out:
# id
# EC06F063-9DF0-440C-8764-0B0C05A4F6AE     854.00
# 4E5F4B3D-DDDF-499D-AFDE-A3227EC49425    1047.00
# E140FF1B-2407-4C02-A0DD-780A093B1158     644.33
# F8D507A0-9C62-4EFE-831E-33E1DA53BB50     768.00
# 4E1C4E78-152B-430A-8094-ADD889C9D0AD     577.00
#                                          ...
# DE633116-D1DF-4846-982E-55EFC3658A76     591.00
# A48374B1-E6DB-45F2-889A-1F9C27C099EB     589.00
# 91643238-5C7B-4237-9A5F-63AE3D35F320     619.00
# 7AFFD323-01D9-4E15-B80D-7D1B03498FC8     601.00
# AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC     607.00
# Name: selling_price, Length: 181668, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((154417, 12), (27251, 12), (154417,), (27251,))

# %%
# sample algorithm for reference
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
result = model.fit(x_train, y_train)

# %%
y_pred = result.predict(x_test)
y_pred
# Out:
# array([802., 591., 872., ..., 537., 890., 594.])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Assuming you have your model and predictions
y_pred = model.predict(x_test)

# Calculate the Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate the Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate the R-squared (R2)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)
# Out:
# Mean Squared Error (MSE): 366965825021.2036
# Root Mean Squared Error (RMSE): 605777.0423358775
# R-squared (R2): -7128264.262818637

# %%
df1 = df
df1
# To save to a CSV file:
df.to_csv('regressor.csv', index=False)

# %%
df1 = df1[(df1['status'] == 1) | (df1['status'] == 7)]
df1['status'].unique()
# Out:
# array([7., 1.])

# %%
df1
# To save to a CSV file:
df.to_csv('classifier.csv', index=False)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150444 entries, EC06F063-9DF0-440C-8764-0B0C05A4F6AE to AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_date      150444 non-null  float64
#  1   quantity tons  150444 non-null  float64
#  2   customer       150444 non-null  float64
#  3   country        150444 non-null  float64
#  4   status         150444 non-null  float64
#  5   item type      150444 non-null  float64
#  6   application    150444 non-null  float64
#  7   thickness      150444 non-null  float64
#  8   width          150444 non-null  float64
#  9   material_ref   150444 non-null  float64
#  10  product_ref    150444 non-null  int64
#  11  delivery date  150444 non-null  float64
#  12  selling_price  150444 non-null  float64
# dtypes: float64(12), int64(1)
# memory usage: 16.1+ MB

# %%
y1 = df1['status']
x1 = df1.drop(['status'], axis = 1)

# %%
df1.status.value_counts()# more than 5%, so balenced
# Out:
# 7.0    116008
# 1.0     34436
# Name: status, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size = 0.15)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((127877, 12), (22567, 12), (127877,), (22567,))

# %%
x_train
# Out:
#                                        item_date  quantity tons    customer  \
# id
# 4EB26710-DE3F-412A-8520-58F6C228FE2D  20201028.0      29.597009  30328008.0
# 28DCE50F-63ED-4AA2-8D1B-AFE0616814C2  20210105.0       1.430480  30300202.0
# 74238408-BEC5-4EF1-9149-CE5B34204349  20210222.0       7.800147  30199273.0
# 1E5C3355-B1FF-4A57-B9B4-76A55ADB8A97  20210119.0       0.802917  30341127.0
# F54252B0-25C0-4027-AF70-995E7082BDF0  20201008.0       4.101214  30202938.0
# ...                                          ...            ...         ...
# 1D76CB07-8EA3-49EC-98D2-FB895BA48704  20210219.0      30.836281  30209332.0
# 18DFDB52-527E-4744-9976-3EE6DD69BACC  20200811.0     201.612378  30341656.0
# F8DF4216-A4B1-4D99-9DF1-49E8FC533655  20200803.0      67.400499  30341927.0
# 5F2BF87B-45B0-400B-A38F-FE87E01683C3  20201216.0     441.881165  30201846.0
# FFE69C1F-72AD-4A12-B319-5139C2D59C79  20201209.0      49.179871  30161088.0
#
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
result = model.fit(x_train, y_train)

# %%
y_pred = result.predict(x_test)
y_pred
# Out:
# array([7., 1., 7., ..., 7., 1., 7.])

# %%
from sklearn import metrics

# %%
print('Accuracy', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy 0.958612132760225

# %%
print('confusion_matrix', metrics.confusion_matrix(y_test, y_pred))
# Out:
# confusion_matrix [[ 4693   469]
#  [  465 16940]]

# %%
print('recall_score', metrics.recall_score(y_test, y_pred)) #
# Out:
# recall_score 0.9091437427353739

# %%
# df['item_date'] = df['item_date'].replace(to_replace='19950000',value='20210401',inplace=True)
# df['delivery date'] = df['delivery date'].replace(to_replace='30310101',value='20210101',inplace=True)
# df['item_date'] = pd.to_datetime(df['item_date'], format='%Y%m%d')
# df['delivery date'] = pd.to_datetime(df['delivery date'], format='%Y%m%d')

# %% [markdown]
# # Reference

# %%
print(max(df['customer']))
min(df['customer'])
# Out:
# 2147483647.0
# 12458.0

# %%
column_names = x1.columns
for i in column_names:
  print(i)
# Out:
# item_date
# quantity tons
# customer
# country
# item type
# application
# thickness
# width
# material_ref
# product_ref
# delivery date
# selling_price

# %%
column_names = x.columns
for i in column_names:
  print(i)
# Out:
# item_date
# quantity tons
# customer
# country
# status
# item type
# application
# thickness
# width
# material_ref
# product_ref
# delivery date
